# %%
from sklearn.metrics import mean_squared_error
import torch
import torch.nn as nn
from torch.autograd import Variable
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Set up

# %%
# set up auto load
# %load_ext autoreload
# %autoreload 2

# %%
from load_data import *
from model import *

plt.rcParams['font.family'] = 'serif'
sns.set_style("darkgrid")

if torch.cuda.is_available():
    device = "cuda:0"
else:
    device = "cpu"
print('PyTorch CUDA is available?', torch.cuda.is_available())
# Out:
# PyTorch CUDA is available? True

# %%
train_ticker_strings = ["AAPL", "AMZN", "CAT", "GOOG", "HSBC", "KO", "JPM", "PCG", "ABB", "BAC", "BP"]
# train_ticker_strings = ["GOOG", "T", "ORCL", "TSM", "VZ", "INTC", "CSCO"]
look_back = 60
train_data_loader = get_data_loader(TransformerAdditionalFeaturesDataset, train_ticker_strings, look_back=look_back)
print("train data size (in batches):", len(train_data_loader))
# Out:
# train data size (in batches): 298

# %%
train_small_data_loader = get_data_loader(TransformerAdditionalFeaturesDataset, train_ticker_strings[:1], look_back=look_back)
print("train small data size (in batches):", len(train_small_data_loader))
# Out:
# train small data size (in batches): 28

# %%
input_dim = 12
hidden_dim = 256
num_layers = 6
output_dim = 1
num_epochs = 50
lr = 0.01
dim_feedforward = 1024
nhead = 4
dropout=0.1
hist = np.zeros(num_epochs)

model = Transformer(
    look_back,
    input_dim,
    hidden_dim=hidden_dim,
    dim_feedforward=dim_feedforward,
    nhead=nhead,
    num_encoder_layers=num_layers,
    dropout=dropout,
    device=device
)
model = model.to(device)

loss_fn = torch.nn.MSELoss()

optimiser = torch.optim.Adam(model.parameters(), lr=lr)
print(model)
print(len(list(model.parameters())))
for i in range(len(list(model.parameters()))):
    print(list(model.parameters())[i].size())
# Out:
# Transformer(
#   (encoder): Encoder(
#     (encoder_layers): ModuleList(
#       (0-5): 6 x EncoderBlock(
#         (multi_head): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=12, out_features=12, bias=True)
#         )
#         (layer_norm1): LayerNorm((12,), eps=1e-05, elementwise_affine=True)
#         (layer_norm2): LayerNorm((12,), eps=1e-05, elementwise_affine=True)
#         (feed_forward): Sequential(
#           (0): Linear(in_features=12, out_features=1024, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=1024, out_features=12, bias=True)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (cross_attention): MultiheadAttention(
#     (out_proj): NonDynamicallyQuantizableLinear(in_features=12, out_features=12, bias=True)
#   )
#   (layer_norm): LayerNorm((12,), eps=1e-05, elementwise_affine=True)
#   (dropout_layer): Dropout(p=0.1, inplace=False)
#   (linear): Linear(in_features=12, out_features=256, bias=True)
#   (relu): ReLU()
#   (linear2): Linear(in_features=256, out_features=1, bias=True)
# )
# 82
# torch.Size([36, 12])
# torch.Size([36])
# torch.Size([12, 12])
# torch.Size([12])
# torch.Size([12])
# torch.Size([12])
# torch.Size([12])
# torch.Size([12])
# torch.Size([1024, 12])
# torch.Size([1024])
# torch.Size([12, 1024])
# torch.Size([12])
# torch.Size([36, 12])
# torch.Size([36])
# torch.Size([12, 12])
# torch.Size([12])
# torch.Size([12])
# torch.Size([12])
# torch.Size([12])
# torch.Size([12])
# torch.Size([1024, 12])
# torch.Size([1024])
# torch.Size([12, 1024])
# torch.Size([12])
# torch.Size([36, 12])
# torch.Size([36])
# torch.Size([12, 12])
# torch.Size([12])
# torch.Size([12])
# torch.Size([12])
# torch.Size([12])
# torch.Size([12])
# torch.Size([1024, 12])
# torch.Size([1024])
# torch.Size([12, 1024])
# torch.Size([12])
# torch.Size([36, 12])
# torch.Size([36])
# torch.Size([12, 12])
# torch.Size([12])
# torch.Size([12])
# torch.Size([12])
# torch.Size([12])
# torch.Size([12])
# torch.Size([1024, 12])
# torch.Size([1024])
# torch.Size([12, 1024])
# torch.Size([12])
# torch.Size([36, 12])
# torch.Size([36])
# torch.Size([12, 12])
# torch.Size([12])
# torch.Size([12])
# torch.Size([12])
# torch.Size([12])
# torch.Size([12])
# torch.Size([1024, 12])
# torch.Size([1024])
# torch.Size([12, 1024])
# torch.Size([12])
# torch.Size([36, 12])
# torch.Size([36])
# torch.Size([12, 12])
# torch.Size([12])
# torch.Size([12])
# torch.Size([12])
# torch.Size([12])
# torch.Size([12])
# torch.Size([1024, 12])
# torch.Size([1024])
# torch.Size([12, 1024])
# torch.Size([12])
# torch.Size([36, 12])
# torch.Size([36])
# torch.Size([12, 12])
# torch.Size([12])
# torch.Size([12])
# torch.Size([12])
# torch.Size([256, 12])
# torch.Size([256])
# torch.Size([1, 256])
# torch.Size([1])

# %%
# try model on small dataset
for t in range(num_epochs):
    total_loss = 0
    # y_train_preds = []
    for X_train, y_train in train_small_data_loader:
        X_train = X_train.to(device)

        # Forward pass
        y_train_pred = model(X_train)
        # y_train_preds.extend(y_train_pred)

        loss = loss_fn(y_train_pred, y_train.to(device))

        total_loss += loss.item()

        # Zero out gradient, else they will accumulate between epochs
        optimiser.zero_grad()

        # Backward pass
        loss.backward()
        # Update parameters
        optimiser.step()

    hist[t] = total_loss
    if t % 10 == 0 and t !=0:
        print("Epoch ", t, "MSE: ", total_loss)
# Out:
# Epoch  10 MSE:  1.7222666912712157
# Epoch  20 MSE:  1.4115833774849307
# Epoch  30 MSE:  1.5821483619511127
# Epoch  40 MSE:  1.5504899013321847

# %%
input_dim = 12
hidden_dim = 256
num_layers = 6
output_dim = 1
num_epochs = 300
lr = 0.001
dim_feedforward = 1024
nhead = 4
dropout=0.1
hist = np.zeros(num_epochs)

model = Transformer(
    look_back,
    input_dim,
    hidden_dim=hidden_dim,
    dim_feedforward=dim_feedforward,
    nhead=nhead,
    num_encoder_layers=num_layers,
    dropout=dropout,
    device=device
)
model = model.to(device)
loss_fn = torch.nn.MSELoss()
optimiser = torch.optim.Adam(model.parameters(), lr=lr)


# train the model
for t in range(num_epochs):
    total_loss = 0
    # y_train_preds = []
    for X_train, y_train in train_data_loader:
        X_train = X_train.to(device)

        # Forward pass
        y_train_pred = model(X_train)
        # y_train_preds.extend(y_train_pred)

        loss = loss_fn(y_train_pred, y_train.to(device))

        total_loss += loss.item()

        # Zero out gradient, else they will accumulate between epochs
        optimiser.zero_grad()

        # Backward pass
        loss.backward()
        # Update parameters
        optimiser.step()

    hist[t] = total_loss
    if t % 10 == 0 and t !=0:
        print("Epoch ", t, "MSE: ", total_loss)
# Out:
# Epoch  10 MSE:  15.743288950063288
# Epoch  20 MSE:  15.216095778159797
# Epoch  30 MSE:  14.763196687214077
# Epoch  40 MSE:  14.596683114767075
# Epoch  50 MSE:  14.5508480258286
# Epoch  60 MSE:  14.539065862074494
# Epoch  70 MSE:  14.475205067545176
# Epoch  80 MSE:  14.315970869734883
# Epoch  90 MSE:  14.409596416167915
# Epoch  100 MSE:  14.318774201907218
# Epoch  110 MSE:  14.356247432529926
# Epoch  120 MSE:  14.110600394196808
# Epoch  130 MSE:  14.271587415598333
# Epoch  140 MSE:  14.168308434076607
# Epoch  150 MSE:  14.172506073489785
# Epoch  160 MSE:  14.084295547567308
# Epoch  170 MSE:  13.942145589739084
# Epoch  180 MSE:  13.975651828572154
# Epoch  190 MSE:  14.088315145112574
# Epoch  200 MSE:  14.010296400636435
# Epoch  210 MSE:  14.032781602814794
# Epoch  220 MSE:  13.981498486362398
# Epoch  230 MSE:  13.948163447901607
# Epoch  240 MSE:  13.933728101663291
# Epoch  250 MSE:  13.976497605443
# Epoch  260 MSE:  13.883509517647326
# Epoch  270 MSE:  13.87834834586829
# Epoch  280 MSE:  13.89235756918788
# Epoch  290 MSE:  13.78844760172069

# %%
figure, axes = plt.subplots(figsize=(6, 4))
plt.plot(range(num_epochs), hist)
plt.xlabel("Epoch")
plt.ylabel("MSE")
plt.title("Loss")
# Out:
# Text(0.5, 1.0, 'Loss')

# %%
test_ticker_string = ['MSFT']
test_data_loader = get_data_loader(TransformerAdditionalFeaturesDataset, test_ticker_string, look_back=look_back, shuffle=False, train=False)
predicted_ticker = test_ticker_string[0]
print("test data sze (in batches):", len(test_data_loader))
# Out:
# test data sze (in batches): 28

# %%
# make predictions
y_tests = []
y_test_preds = []
for X_test, y_test in test_data_loader:
    X_test = X_test.to(device)
    y_tests.extend(y_test)
    pred = model(X_test)
    pred = pred.detach().cpu()
    y_test_preds.extend(pred)

# y_tests = test_data_loader.dataset.df['Adj Close'][look_back:].values
y_tests = torch.stack(y_tests).cpu().detach().numpy()
y_test_preds = torch.stack(y_test_preds).cpu().detach().numpy()

# calculate root mean squared error
testScore = (mean_squared_error(y_tests, y_test_preds))
print('Test Score: %.5f MSE' % (testScore))

y_tests = test_data_loader.dataset.df['adj.close']
y_tests = np.array(y_tests)
# N, 1 -> N, 1, D
y_test_preds = np.expand_dims(y_test_preds, axis=2).repeat(input_dim, axis=2)
# N, 1
y_test_preds = test_data_loader.dataset.invert_transform(y_test_preds)
test_price_score = np.sqrt(mean_squared_error(y_tests, y_test_preds))
print('Test Price Score: %.2f RMSE' % (test_price_score))
# Out:
# Test Score: 0.06434 MSE
# Test Price Score: 0.64 RMSE

# %%
# Visualising the results
figure, axes = plt.subplots(figsize=(30, 6))

axes.xaxis_date()

df = test_data_loader.dataset.df

# axes.plot(df.index[1:], y_tests[:-1], color = 'red', label = 'Real Stock Price')
# axes.plot(df.index[1:], y_test_preds[1:,0], color = 'blue', label = 'Predicted Stock Price')
axes.plot(df.index, y_tests, color = 'red', label = 'Real Stock Price')
axes.plot(df.index, y_test_preds[:,0], color = 'blue', label = 'Predicted Stock Price')
#axes.xticks(np.arange(0,394,50))
plt.title(f'Transformer Stock Price Prediction: {predicted_ticker}')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.savefig(f'./plots/transformer1_pred_{predicted_ticker}.png')
plt.show()

# %%
correct_pred = 0
incorrect_pred = 0
for i in range(1, len(y_tests)):
    if (y_tests[i] - y_tests[i-1]) * (y_test_preds[i] - y_tests[i-1]) > 0:
        correct_pred += 1
    else:
        incorrect_pred += 1

print("Accuracy of predicting rise/drop: ", correct_pred / (correct_pred + incorrect_pred))
# Out:
# Accuracy of predicting rise/drop:  0.49189814814814814

# %%
save_path = './models/transformer_addditional_features_model.pth'

# Save the model to file
torch.save(model.state_dict(), save_path)
